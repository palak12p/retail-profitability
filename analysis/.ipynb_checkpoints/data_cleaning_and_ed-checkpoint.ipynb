# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv('../data/retail_sales_data.csv')
df['Date'] = pd.to_datetime(df['Date'])

# View basic info
df.head()
# Out:
# Matplotlib is building the font cache; this may take a moment.
#         Date    Store      City     Product       Category  Unit_Price  \
# 0 2024-01-01  Store_1   Lucknow   Product_6     Stationery      175.99
# 1 2024-01-01  Store_1  Varanasi  Product_41     Stationery       87.11
# 2 2024-01-01  Store_1    Raipur  Product_31  Personal Care      470.01
# 3 2024-01-01  Store_1   Udaipur   Product_3  Personal Care      190.63
# 4 2024-01-01  Store_1  Jabalpur  Product_30         Snacks       72.85
#
#    Quantity  Revenue     Cost
# 0         4   703.96   519.77
# 1         1    87.11    75.53
# 2         3  1410.03  1232.84
# 3         2   381.26   324.14
# 4         4   291.40   246.84

# %%
df['Profit'] = df['Revenue'] - df['Cost']

# %%
store_profit = df.groupby('Store')['Profit'].sum().sort_values(ascending=False)
print("🔝 Top 5 Most Profitable Stores:")
print(store_profit.head())

store_profit.plot(kind='bar', figsize=(12,5), title='Store-wise Profit')
plt.ylabel("Profit (₹)")
plt.tight_layout()
plt.show()
# Out:
# 🔝 Top 5 Most Profitable Stores:
# Store
# Store_22    146298.76
# Store_25    145048.97
# Store_23    144361.48
# Store_1     144140.20
# Store_9     143862.95
# Name: Profit, dtype: float64

# %%
category_profit = df.groupby('Category')[['Revenue', 'Profit']].sum().sort_values(by='Profit', ascending=False)
print("\n📊 Category-wise Performance:")
print(category_profit)

category_profit['Profit'].plot(kind='bar', color='orange', title='Category-wise Profit', figsize=(8,4))
plt.ylabel("Profit (₹)")
plt.tight_layout()
plt.show()
# Out:
# 📊 Category-wise Performance:
#                   Revenue     Profit
# Category
# Personal Care  2860566.24  710934.05
# Beverages      2825959.23  705415.72
# Stationery     2763943.60  697994.40
# Snacks         2784519.26  692666.87
# Grocery        2750285.93  686233.21

# %%
daily_revenue = df.groupby('Date')['Revenue'].sum()

plt.figure(figsize=(12,4))
plt.plot(daily_revenue)
plt.title("📈 Daily Revenue Trend")
plt.xlabel("Date")
plt.ylabel("Revenue (₹)")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9y/vkls5yjn17b9rcnl1fl9v98h0000gn/T/ipykernel_5159/3027969905.py:8: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
deadstock = df.groupby('Product')['Quantity'].sum().sort_values().head(10)
print("🛑 Least Sold Products:")
print(deadstock)
# Out:
# 🛑 Least Sold Products:
# Product
# Product_9      913
# Product_27     926
# Product_22     935
# Product_50     960
# Product_13     989
# Product_20    1009
# Product_43    1019
# Product_18    1020
# Product_25    1021
# Product_36    1022
# Name: Quantity, dtype: int64
